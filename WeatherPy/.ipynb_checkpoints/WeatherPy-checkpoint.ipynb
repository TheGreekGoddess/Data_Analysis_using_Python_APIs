# %% [markdown]
# # WeatherPy
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
import json
import requests

# Install citipy to look for the nearest city with geo coordinates
# !pip install citipy

# Import API key
from api_keys import weather_api_key

# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)
# Out:
# Requirement already satisfied: citipy in c:\users\orodrigues\anaconda3\lib\site-packages (0.0.5)
# Requirement already satisfied: kdtree>=0.12 in c:\users\orodrigues\anaconda3\lib\site-packages (from citipy) (0.16)

# %% [markdown]
# ## Generate Cities List

# %%
# List for holding latitude, longitudes and cities
lat_lngs = []
cities = []

# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each latitude and longitude combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 608

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it's being processed (with the city number and city name).

# %%
# Set url for API
base_url = "http://api.openweathermap.org/data/2.5/weather?"

# Test for one city
test_city = "Madgaon"

# Build the query URL
test_url = base_url + "appid=" + weather_api_key + "&q=" + test_city
print(test_url)

# Get weather data
test_json = requests.get(test_url).json()

# Print the weather data for the test city to discover all available fields
print (json.dumps(test_json, indent = 4, sort_keys = True))
# Out:
# http://api.openweathermap.org/data/2.5/weather?appid=a40a69c36b0886d82e86a271f94a8db0&q=Madgaon
# {
#     "base": "stations",
#     "clouds": {
#         "all": 75
#     },
#     "cod": 200,
#     "coord": {
#         "lat": 15.3,
#         "lon": 73.95
#     },
#     "dt": 1592781324,
#     "id": 1264588,
#     "main": {
#         "feels_like": 302.13,
#         "humidity": 94,
#         "pressure": 1004,
#         "temp": 298.15,
#         "temp_max": 298.15,
#         "temp_min": 298.15
#     },
#     "name": "Madgaon",
#     "sys": {
#         "country": "IN",
#         "id": 9233,
#         "sunrise": 1592786110,
#         "sunset": 1592833033,
#         "type": 1
#     },
#     "timezone": 19800,
#     "visibility": 5000,
#     "weather": [
#         {
#             "description": "mist",
#             "icon": "50n",
#             "id": 701,
#             "main": "Mist"
#         }
#     ],
#     "wind": {
#         "deg": 210,
#         "speed": 2.6
#     }
# }

# %%
# Create empty lists to collect and store the corresponding raw data using a series of successive API calls
city_data = []
        
# Set a counter to print the requested results with record number
record_number = 1
        
# Loop through each city
for city in cities:
    
    # Create search query, make request and store in json
    units = "Imperial"
    query_url = base_url + "appid=" + weather_api_key + "&q=" + city + "&units=" + units
    weather_json = requests.get(query_url).json()
    
    # Collect the raw data values if they are available in the Open Weather Map API
    try:
        city_name = (weather_json['name'])
        country = (weather_json['sys']['country'])        
        latitude = (weather_json['coord']['lat'])
        longitude = (weather_json['coord']['lon'])
        temperature = (weather_json['main']['temp_max'])
        humidity = (weather_json['main']['humidity'])        
        wind_speed = (weather_json['wind']['speed'])
        cloudiness = (weather_json['clouds']['all'])
        datetime = (weather_json['dt'])
        
        # Create dictionaries to append with the values as the loop iterates
        city_data.append({
            "City": city_name,
            "Country": country,
            "Latitude": latitude,
            "Longitude": longitude,
            "Temperature (F)": temperature,
            "Humidity (%)": humidity,
            "Wind speed (mph)": wind_speed,
            "Cloud coverage": cloudiness,
            "Datetime": datetime,
        })
        
        print (f"Processing record {record_number} of Set 1 | {city}")

    # Handle exceptions for a city that is not available in the Open Weather Map API
    except:
        # Append null values
        print(f"Processing record {record_number} of Set 1 | {city} not found. Skipping...")
        pass
    record_number += 1
    
print("Great job! All raw data has now been collected")
# Out:
# Processing record 1 of Set 1 | vaini
# Processing record 2 of Set 1 | bonavista
# Processing record 3 of Set 1 | salalah
# Processing record 4 of Set 1 | butaritari
# Processing record 5 of Set 1 | hobart
# Processing record 6 of Set 1 | bacuit not found. Skipping...
# Processing record 7 of Set 1 | margate
# Processing record 8 of Set 1 | ribeira grande
# Processing record 9 of Set 1 | avarua
# Processing record 10 of Set 1 | tasiilaq
# Processing record 11 of Set 1 | ushuaia
# Processing record 12 of Set 1 | illoqqortoormiut not found. Skipping...
# Processing record 13 of Set 1 | hovd
# Processing record 14 of Set 1 | marfino
# Processing record 15 of Set 1 | airai
# Processing record 16 of Set 1 | barrow
# Processing record 17 of Set 1 | new norfolk
# Processing record 18 of Set 1 | sitka
# Processing record 19 of Set 1 | khatanga
# Processing record 20 of Set 1 | peace river
# Processing record 21 of Set 1 | severnoye
# Processing record 22 of Set 1 | bluff
# Processing record 23 of Set 1 | lebu
# Processing record 24 of Set 1 | comodoro rivadavia
# Processing record 25 of Set 1 | bambous virieux
# Processing record 26 of Set 1 | athenree
# Processing record 27 of Set 1 | saleaula not found. Skipping...
# Processing record 28 of Set 1 | punta arenas
# Processing record 29 of Set 1 | daru
# Processing record 30 of Set 1 | dongsheng
# Processing record 31 of Set 1 | grand river south east not found. Skipping...
# Processing record 32 of Set 1 | joshimath
# Processing record 33 of Set 1 | bredasdorp
# Processing record 34 of Set 1 | taolanaro not found. Skipping...
# Processing record 35 of Set 1 | mataura
# Processing record 36 of Set 1 | bathsheba
# Processing record 37 of Set 1 | saint-philippe
# Processing record 38 of Set 1 | chokurdakh
# Processing record 39 of Set 1 | tsihombe not found. Skipping...
# Processing record 40 of Set 1 | fortuna
# Processing record 41 of Set 1 | waingapu
# Processing record 42 of Set 1 | pevek
# Processing record 43 of Set 1 | dunedin
# Processing record 44 of Set 1 | east london
# Processing record 45 of Set 1 | pangoa
# Processing record 46 of Set 1 | sakakah
# Processing record 47 of Set 1 | kapaa
# Processing record 48 of Set 1 | dawlatabad
# Processing record 49 of Set 1 | arraial do cabo
# Processing record 50 of Set 1 | rikitea
# Processing record 51 of Set 1 | busselton
# Processing record 52 of Set 1 | mar del plata
# Processing record 53 of Set 1 | noshiro
# Processing record 54 of Set 1 | tuatapere
# Processing record 55 of Set 1 | souillac
# Processing record 56 of Set 1 | mahebourg
# Processing record 57 of Set 1 | saint george
# Processing record 58 of Set 1 | quelimane
# Processing record 59 of Set 1 | spisske podhradie
# Processing record 60 of Set 1 | leningradskiy
# Processing record 61 of Set 1 | hami
# Processing record 62 of Set 1 | san cristobal
# Processing record 63 of Set 1 | ormara
# Processing record 64 of Set 1 | marcona not found. Skipping...
# Processing record 65 of Set 1 | benalla
# Processing record 66 of Set 1 | san juan
# Processing record 67 of Set 1 | la calera
# Processing record 68 of Set 1 | achisay not found. Skipping...
# Processing record 69 of Set 1 | svetlaya
# Processing record 70 of Set 1 | lyubashivka
# Processing record 71 of Set 1 | viligili not found. Skipping...
# Processing record 72 of Set 1 | asau
# Processing record 73 of Set 1 | inhambane
# Processing record 74 of Set 1 | yanchukan not found. Skipping...
# Processing record 75 of Set 1 | sao gabriel da cachoeira
# Processing record 76 of Set 1 | mount gambier
# Processing record 77 of Set 1 | barentsburg not found. Skipping...
# Processing record 78 of Set 1 | rio gallegos
# Processing record 79 of Set 1 | atuona
# Processing record 80 of Set 1 | upernavik
# Processing record 81 of Set 1 | bonfim
# Processing record 82 of Set 1 | valparaiso
# Processing record 83 of Set 1 | puerto ayora
# Processing record 84 of Set 1 | jumla
# Processing record 85 of Set 1 | acurenam
# Processing record 86 of Set 1 | mogadishu
# Processing record 87 of Set 1 | narsaq
# Processing record 88 of Set 1 | lampang
# Processing record 89 of Set 1 | tautira
# Processing record 90 of Set 1 | hithadhoo
# Processing record 91 of Set 1 | ponta do sol
# Processing record 92 of Set 1 | nizhneyansk not found. Skipping...
# Processing record 93 of Set 1 | goure
# Processing record 94 of Set 1 | horasan
# Processing record 95 of Set 1 | xifeng
# Processing record 96 of Set 1 | port keats
# Processing record 97 of Set 1 | natalinsk
# Processing record 98 of Set 1 | sunbury
# Processing record 99 of Set 1 | road town
# Processing record 100 of Set 1 | mattru
# Processing record 101 of Set 1 | faanui
# Processing record 102 of Set 1 | hualmay
# Processing record 103 of Set 1 | sahrak not found. Skipping...
# Processing record 104 of Set 1 | baijiantan
# Processing record 105 of Set 1 | morro bay
# Processing record 106 of Set 1 | jamestown
# Processing record 107 of Set 1 | sentyabrskiy not found. Skipping...
# Processing record 108 of Set 1 | pisco
# Processing record 109 of Set 1 | nikolskoye
# Processing record 110 of Set 1 | tekeli
# Processing record 111 of Set 1 | scottsburgh not found. Skipping...
# Processing record 112 of Set 1 | cidreira
# Processing record 113 of Set 1 | mutis
# Processing record 114 of Set 1 | ancud
# Processing record 115 of Set 1 | brigantine
# Processing record 116 of Set 1 | camopi
# Processing record 117 of Set 1 | thompson
# Processing record 118 of Set 1 | mahibadhoo
# Processing record 119 of Set 1 | cabo san lucas
# Processing record 120 of Set 1 | hilo
# Processing record 121 of Set 1 | sept-iles
# Processing record 122 of Set 1 | lahat
# Processing record 123 of Set 1 | itambacuri
# Processing record 124 of Set 1 | doha
# Processing record 125 of Set 1 | kodiak
# Processing record 126 of Set 1 | bilibino
# Processing record 127 of Set 1 | peniche
# Processing record 128 of Set 1 | roebourne
# Processing record 129 of Set 1 | zabaykalsk
# Processing record 130 of Set 1 | saskylakh
# Processing record 131 of Set 1 | montrose
# Processing record 132 of Set 1 | sovetskiy
# Processing record 133 of Set 1 | jining
# Processing record 134 of Set 1 | yellowknife
# Processing record 135 of Set 1 | santa fe
# Processing record 136 of Set 1 | luderitz
# Processing record 137 of Set 1 | belushya guba not found. Skipping...
# Processing record 138 of Set 1 | bethel
# Processing record 139 of Set 1 | albany
# Processing record 140 of Set 1 | victoria
# Processing record 141 of Set 1 | lakhnau
# Processing record 142 of Set 1 | tuktoyaktuk
# Processing record 143 of Set 1 | zabolottya not found. Skipping...
# Processing record 144 of Set 1 | buzdyak
# Processing record 145 of Set 1 | sao filipe
# Processing record 146 of Set 1 | kulu
# Processing record 147 of Set 1 | lavrentiya
# Processing record 148 of Set 1 | ugoofaaru
# Processing record 149 of Set 1 | oranjemund
# Processing record 150 of Set 1 | kavaratti
# Processing record 151 of Set 1 | trinidad
# Processing record 152 of Set 1 | samusu not found. Skipping...
# Processing record 153 of Set 1 | urucui
# Processing record 154 of Set 1 | ahwa
# Processing record 155 of Set 1 | nome
# Processing record 156 of Set 1 | iqaluit
# Processing record 157 of Set 1 | lata
# Processing record 158 of Set 1 | catuday
# Processing record 159 of Set 1 | severo-kurilsk
# Processing record 160 of Set 1 | arman
# Processing record 161 of Set 1 | qaanaaq
# Processing record 162 of Set 1 | ngukurr not found. Skipping...
# Processing record 163 of Set 1 | wanning
# Processing record 164 of Set 1 | gangotri not found. Skipping...
# Processing record 165 of Set 1 | bonthe
# Processing record 166 of Set 1 | north bend
# Processing record 167 of Set 1 | nouadhibou
# Processing record 168 of Set 1 | mizan teferi
# Processing record 169 of Set 1 | roald
# Processing record 170 of Set 1 | makakilo city
# Processing record 171 of Set 1 | college
# Processing record 172 of Set 1 | puerto montt
# Processing record 173 of Set 1 | provideniya
# Processing record 174 of Set 1 | saint-leu
# Processing record 175 of Set 1 | sinnamary
# Processing record 176 of Set 1 | bengkulu
# Processing record 177 of Set 1 | prince rupert
# Processing record 178 of Set 1 | dikson
# Processing record 179 of Set 1 | mount isa
# Processing record 180 of Set 1 | kupang
# Processing record 181 of Set 1 | port elizabeth
# Processing record 182 of Set 1 | touros
# Processing record 183 of Set 1 | port alfred
# Processing record 184 of Set 1 | nueva guinea
# Processing record 185 of Set 1 | chubbuck
# Processing record 186 of Set 1 | braslav not found. Skipping...
# Processing record 187 of Set 1 | moerai
# Processing record 188 of Set 1 | zhigansk
# Processing record 189 of Set 1 | khonuu not found. Skipping...
# Processing record 190 of Set 1 | gazanjyk
# Processing record 191 of Set 1 | padampur
# Processing record 192 of Set 1 | hermanus
# Processing record 193 of Set 1 | ilulissat
# Processing record 194 of Set 1 | novyy urgal
# Processing record 195 of Set 1 | noumea
# Processing record 196 of Set 1 | longyearbyen
# Processing record 197 of Set 1 | cape town
# Processing record 198 of Set 1 | georgetown
# Processing record 199 of Set 1 | wladyslawowo
# Processing record 200 of Set 1 | samalaeulu not found. Skipping...
# Processing record 201 of Set 1 | chuy
# Processing record 202 of Set 1 | tahoua
# Processing record 203 of Set 1 | alofi
# Processing record 204 of Set 1 | itoman
# Processing record 205 of Set 1 | kavieng
# Processing record 206 of Set 1 | sochi
# Processing record 207 of Set 1 | alyangula
# Processing record 208 of Set 1 | maun
# Processing record 209 of Set 1 | coquimbo
# Processing record 210 of Set 1 | attawapiskat not found. Skipping...
# Processing record 211 of Set 1 | mezen
# Processing record 212 of Set 1 | kaitangata
# Processing record 213 of Set 1 | salekhard
# Processing record 214 of Set 1 | clyde river
# Processing record 215 of Set 1 | nyurba
# Processing record 216 of Set 1 | aklavik
# Processing record 217 of Set 1 | houston
# Processing record 218 of Set 1 | vila
# Processing record 219 of Set 1 | vila velha
# Processing record 220 of Set 1 | torbay
# Processing record 221 of Set 1 | odzak
# Processing record 222 of Set 1 | phibun mangsahan
# Processing record 223 of Set 1 | puerto escondido
# Processing record 224 of Set 1 | avera
# Processing record 225 of Set 1 | erzin
# Processing record 226 of Set 1 | yerbogachen
# Processing record 227 of Set 1 | umm lajj
# Processing record 228 of Set 1 | la paz
# Processing record 229 of Set 1 | quatre cocos
# Processing record 230 of Set 1 | mitsamiouli
# Processing record 231 of Set 1 | cherskiy
# Processing record 232 of Set 1 | malanje
# Processing record 233 of Set 1 | hay river
# Processing record 234 of Set 1 | san policarpo
# Processing record 235 of Set 1 | hasaki
# Processing record 236 of Set 1 | cache creek
# Processing record 237 of Set 1 | chivacoa
# Processing record 238 of Set 1 | nantucket
# Processing record 239 of Set 1 | rawson
# Processing record 240 of Set 1 | pacific grove
# Processing record 241 of Set 1 | kaduna
# Processing record 242 of Set 1 | ust-uda
# Processing record 243 of Set 1 | awbari
# Processing record 244 of Set 1 | rancho palos verdes
# Processing record 245 of Set 1 | nuuk
# Processing record 246 of Set 1 | praia
# Processing record 247 of Set 1 | zhicheng
# Processing record 248 of Set 1 | saldanha
# Processing record 249 of Set 1 | sungai padi
# Processing record 250 of Set 1 | pangnirtung
# Processing record 251 of Set 1 | mollendo
# Processing record 252 of Set 1 | fairbanks
# Processing record 253 of Set 1 | gimbi
# Processing record 254 of Set 1 | anito
# Processing record 255 of Set 1 | otradnoye
# Processing record 256 of Set 1 | antofagasta
# Processing record 257 of Set 1 | nanortalik
# Processing record 258 of Set 1 | belyy yar
# Processing record 259 of Set 1 | carnarvon
# Processing record 260 of Set 1 | isiro
# Processing record 261 of Set 1 | kargasok
# Processing record 262 of Set 1 | fort nelson
# Processing record 263 of Set 1 | sisimiut
# Processing record 264 of Set 1 | emerald
# Processing record 265 of Set 1 | vaitupu not found. Skipping...
# Processing record 266 of Set 1 | kyabe
# Processing record 267 of Set 1 | seminole
# Processing record 268 of Set 1 | parana
# Processing record 269 of Set 1 | yumen
# Processing record 270 of Set 1 | lagoa
# Processing record 271 of Set 1 | alakurtti
# Processing record 272 of Set 1 | srednekolymsk
# Processing record 273 of Set 1 | patnos
# Processing record 274 of Set 1 | tortoli
# Processing record 275 of Set 1 | bemidji
# Processing record 276 of Set 1 | satitoa not found. Skipping...
# Processing record 277 of Set 1 | denia
# Processing record 278 of Set 1 | lompoc
# Processing record 279 of Set 1 | camacha
# Processing record 280 of Set 1 | snasa
# Processing record 281 of Set 1 | amderma not found. Skipping...
# Processing record 282 of Set 1 | abonnema
# Processing record 283 of Set 1 | mayumba
# Processing record 284 of Set 1 | armacao dos buzios not found. Skipping...
# Processing record 285 of Set 1 | bubaque
# Processing record 286 of Set 1 | kars
# Processing record 287 of Set 1 | kontagora
# Processing record 288 of Set 1 | kismayo
# Processing record 289 of Set 1 | labateca
# Processing record 290 of Set 1 | chapais
# Processing record 291 of Set 1 | labuhan
# Processing record 292 of Set 1 | zalantun
# Processing record 293 of Set 1 | kirakira
# Processing record 294 of Set 1 | te anau
# Processing record 295 of Set 1 | magadan
# Processing record 296 of Set 1 | qostanay
# Processing record 297 of Set 1 | tonstad
# Processing record 298 of Set 1 | isangel
# Processing record 299 of Set 1 | hobyo
# Processing record 300 of Set 1 | tvoroyri
# Processing record 301 of Set 1 | jardim
# Processing record 302 of Set 1 | umzimvubu not found. Skipping...
# Processing record 303 of Set 1 | abbeville
# Processing record 304 of Set 1 | alindao
# Processing record 305 of Set 1 | muroto
# Processing record 306 of Set 1 | along
# Processing record 307 of Set 1 | loandjili
# Processing record 308 of Set 1 | takoradi
# Processing record 309 of Set 1 | launceston
# Processing record 310 of Set 1 | zabol
# Processing record 311 of Set 1 | san luis
# Processing record 312 of Set 1 | pleasanton
# Processing record 313 of Set 1 | kawalu
# Processing record 314 of Set 1 | saint-augustin
# Processing record 315 of Set 1 | akom
# Processing record 316 of Set 1 | alice springs
# Processing record 317 of Set 1 | beringovskiy
# Processing record 318 of Set 1 | oranjestad
# Processing record 319 of Set 1 | colesberg
# Processing record 320 of Set 1 | sao joao da barra
# Processing record 321 of Set 1 | southbridge
# Processing record 322 of Set 1 | katsuura
# Processing record 323 of Set 1 | hofn
# Processing record 324 of Set 1 | nagua
# Processing record 325 of Set 1 | atherton
# Processing record 326 of Set 1 | imeni telmana not found. Skipping...
# Processing record 327 of Set 1 | helong
# Processing record 328 of Set 1 | grindavik
# Processing record 329 of Set 1 | acapulco
# Processing record 330 of Set 1 | sirajganj
# Processing record 331 of Set 1 | simao
# Processing record 332 of Set 1 | karatau
# Processing record 333 of Set 1 | pemangkat
# Processing record 334 of Set 1 | soller
# Processing record 335 of Set 1 | palabuhanratu not found. Skipping...
# Processing record 336 of Set 1 | luanda
# Processing record 337 of Set 1 | mys shmidta not found. Skipping...
# Processing record 338 of Set 1 | umm durman not found. Skipping...
# Processing record 339 of Set 1 | mount pleasant
# Processing record 340 of Set 1 | am timan
# Processing record 341 of Set 1 | norman wells
# Processing record 342 of Set 1 | anadyr
# Processing record 343 of Set 1 | catamarca
# Processing record 344 of Set 1 | citta di castello
# Processing record 345 of Set 1 | blackwater
# Processing record 346 of Set 1 | kuytun
# Processing record 347 of Set 1 | lulea
# Processing record 348 of Set 1 | katobu
# Processing record 349 of Set 1 | lorengau
# Processing record 350 of Set 1 | san diego de la union
# Processing record 351 of Set 1 | matagami
# Processing record 352 of Set 1 | khani
# Processing record 353 of Set 1 | nanakuli
# Processing record 354 of Set 1 | baykit
# Processing record 355 of Set 1 | aplahoue
# Processing record 356 of Set 1 | porto novo
# Processing record 357 of Set 1 | arroyo
# Processing record 358 of Set 1 | vilhena
# Processing record 359 of Set 1 | roma
# Processing record 360 of Set 1 | tiksi
# Processing record 361 of Set 1 | hihifo not found. Skipping...
# Processing record 362 of Set 1 | kloulklubed
# Processing record 363 of Set 1 | khandyga
# Processing record 364 of Set 1 | broome
# Processing record 365 of Set 1 | saint-pierre
# Processing record 366 of Set 1 | sosnovo-ozerskoye
# Processing record 367 of Set 1 | gizo
# Processing record 368 of Set 1 | west plains
# Processing record 369 of Set 1 | westport
# Processing record 370 of Set 1 | nemuro
# Processing record 371 of Set 1 | coahuayana
# Processing record 372 of Set 1 | ijaki not found. Skipping...
# Processing record 373 of Set 1 | jose bonifacio
# Processing record 374 of Set 1 | ngunguru
# Processing record 375 of Set 1 | kruisfontein
# Processing record 376 of Set 1 | cayenne
# Processing record 377 of Set 1 | alta floresta
# Processing record 378 of Set 1 | godec not found. Skipping...
# Processing record 379 of Set 1 | kalevala
# Processing record 380 of Set 1 | mabaruma
# Processing record 381 of Set 1 | mulege
# Processing record 382 of Set 1 | albury
# Processing record 383 of Set 1 | sirsa
# Processing record 384 of Set 1 | kelo
# Processing record 385 of Set 1 | viedma
# Processing record 386 of Set 1 | roding
# Processing record 387 of Set 1 | tapaua not found. Skipping...
# Processing record 388 of Set 1 | onega
# Processing record 389 of Set 1 | nivala
# Processing record 390 of Set 1 | mahenge
# Processing record 391 of Set 1 | codajas
# Processing record 392 of Set 1 | kaeo
# Processing record 393 of Set 1 | ambilobe
# Processing record 394 of Set 1 | sandy bay
# Processing record 395 of Set 1 | tamandare
# Processing record 396 of Set 1 | garowe
# Processing record 397 of Set 1 | saint anthony
# Processing record 398 of Set 1 | rabo de peixe
# Processing record 399 of Set 1 | adrar
# Processing record 400 of Set 1 | klaksvik
# Processing record 401 of Set 1 | louisbourg not found. Skipping...
# Processing record 402 of Set 1 | caravelas
# Processing record 403 of Set 1 | kalmunai
# Processing record 404 of Set 1 | inongo
# Processing record 405 of Set 1 | marawi
# Processing record 406 of Set 1 | bud
# Processing record 407 of Set 1 | palauig
# Processing record 408 of Set 1 | sibolga
# Processing record 409 of Set 1 | portland
# Processing record 410 of Set 1 | vizimyary not found. Skipping...
# Processing record 411 of Set 1 | mongoumba
# Processing record 412 of Set 1 | los llanos de aridane
# Processing record 413 of Set 1 | obo
# Processing record 414 of Set 1 | sambava
# Processing record 415 of Set 1 | abasolo
# Processing record 416 of Set 1 | wilkie
# Processing record 417 of Set 1 | auburn
# Processing record 418 of Set 1 | zhuhai
# Processing record 419 of Set 1 | bandarbeyla
# Processing record 420 of Set 1 | guerrero negro
# Processing record 421 of Set 1 | sortland
# Processing record 422 of Set 1 | san quintin
# Processing record 423 of Set 1 | camiri
# Processing record 424 of Set 1 | talcahuano
# Processing record 425 of Set 1 | ahipara
# Processing record 426 of Set 1 | kamenskoye not found. Skipping...
# Processing record 427 of Set 1 | shimoda
# Processing record 428 of Set 1 | edd
# Processing record 429 of Set 1 | kahului
# Processing record 430 of Set 1 | archidona
# Processing record 431 of Set 1 | marystown
# Processing record 432 of Set 1 | mitchell
# Processing record 433 of Set 1 | teodoro sampaio
# Processing record 434 of Set 1 | iralaya
# Processing record 435 of Set 1 | tessalit
# Processing record 436 of Set 1 | lolua not found. Skipping...
# Processing record 437 of Set 1 | kalpi
# Processing record 438 of Set 1 | madaripur
# Processing record 439 of Set 1 | pangody
# Processing record 440 of Set 1 | ust-kamchatsk not found. Skipping...
# Processing record 441 of Set 1 | bereda
# Processing record 442 of Set 1 | sharjah
# Processing record 443 of Set 1 | chimichagua
# Processing record 444 of Set 1 | dinguiraye
# Processing record 445 of Set 1 | plettenberg bay
# Processing record 446 of Set 1 | oyama
# Processing record 447 of Set 1 | tupik
# Processing record 448 of Set 1 | bulgan
# Processing record 449 of Set 1 | hambantota
# Processing record 450 of Set 1 | komsomolskiy
# Processing record 451 of Set 1 | massakory
# Processing record 452 of Set 1 | mocuba
# Processing record 453 of Set 1 | karimganj
# Processing record 454 of Set 1 | ghanzi
# Processing record 455 of Set 1 | muli
# Processing record 456 of Set 1 | tay ninh
# Processing record 457 of Set 1 | tashla
# Processing record 458 of Set 1 | marsa matruh
# Processing record 459 of Set 1 | antoing
# Processing record 460 of Set 1 | sundumbili
# Processing record 461 of Set 1 | waipawa
# Processing record 462 of Set 1 | namibe
# Processing record 463 of Set 1 | kenitra
# Processing record 464 of Set 1 | byron bay
# Processing record 465 of Set 1 | quthing
# Processing record 466 of Set 1 | eureka
# Processing record 467 of Set 1 | fairfield
# Processing record 468 of Set 1 | yulara
# Processing record 469 of Set 1 | esperance
# Processing record 470 of Set 1 | puerto baquerizo moreno
# Processing record 471 of Set 1 | rungata not found. Skipping...
# Processing record 472 of Set 1 | castro
# Processing record 473 of Set 1 | biloela
# Processing record 474 of Set 1 | mezimesti
# Processing record 475 of Set 1 | macomb
# Processing record 476 of Set 1 | san vicente
# Processing record 477 of Set 1 | epinal
# Processing record 478 of Set 1 | balkhash
# Processing record 479 of Set 1 | kununurra
# Processing record 480 of Set 1 | codrington
# Processing record 481 of Set 1 | dhangadhi
# Processing record 482 of Set 1 | jieshi
# Processing record 483 of Set 1 | amahai
# Processing record 484 of Set 1 | san juan de la maguana
# Processing record 485 of Set 1 | bintulu
# Processing record 486 of Set 1 | mweka
# Processing record 487 of Set 1 | necochea
# Processing record 488 of Set 1 | shirokiy
# Processing record 489 of Set 1 | marquette
# Processing record 490 of Set 1 | brorup
# Processing record 491 of Set 1 | kubrat
# Processing record 492 of Set 1 | bundaberg
# Processing record 493 of Set 1 | skeldon
# Processing record 494 of Set 1 | vostok
# Processing record 495 of Set 1 | cururupu
# Processing record 496 of Set 1 | iskateley
# Processing record 497 of Set 1 | balsas
# Processing record 498 of Set 1 | concarneau
# Processing record 499 of Set 1 | vestmannaeyjar
# Processing record 500 of Set 1 | maarianhamina
# Processing record 501 of Set 1 | pokhara
# Processing record 502 of Set 1 | taiyuan
# Processing record 503 of Set 1 | chernyshevskiy
# Processing record 504 of Set 1 | tura
# Processing record 505 of Set 1 | richards bay
# Processing record 506 of Set 1 | rognan
# Processing record 507 of Set 1 | wawa
# Processing record 508 of Set 1 | pithora
# Processing record 509 of Set 1 | tabialan not found. Skipping...
# Processing record 510 of Set 1 | merrill
# Processing record 511 of Set 1 | poum
# Processing record 512 of Set 1 | novoorsk
# Processing record 513 of Set 1 | mormugao
# Processing record 514 of Set 1 | dingle
# Processing record 515 of Set 1 | raga
# Processing record 516 of Set 1 | yar-sale
# Processing record 517 of Set 1 | saint-paul
# Processing record 518 of Set 1 | alotau not found. Skipping...
# Processing record 519 of Set 1 | chengde
# Processing record 520 of Set 1 | goba
# Processing record 521 of Set 1 | raduzhnyy
# Processing record 522 of Set 1 | vanavara
# Processing record 523 of Set 1 | robertsport
# Processing record 524 of Set 1 | chimbote
# Processing record 525 of Set 1 | ocumare del tuy
# Processing record 526 of Set 1 | ostrovnoy
# Processing record 527 of Set 1 | lingyuan
# Processing record 528 of Set 1 | rafai
# Processing record 529 of Set 1 | diffa
# Processing record 530 of Set 1 | olafsvik
# Processing record 531 of Set 1 | phalombe
# Processing record 532 of Set 1 | hit
# Processing record 533 of Set 1 | gomel
# Processing record 534 of Set 1 | verkhnyaya inta
# Processing record 535 of Set 1 | uchiza
# Processing record 536 of Set 1 | baley
# Processing record 537 of Set 1 | mugur-aksy
# Processing record 538 of Set 1 | taoudenni
# Processing record 539 of Set 1 | padang
# Processing record 540 of Set 1 | borogontsy
# Processing record 541 of Set 1 | lavumisa
# Processing record 542 of Set 1 | jaicos
# Processing record 543 of Set 1 | bobcaygeon
# Processing record 544 of Set 1 | pithoragarh
# Processing record 545 of Set 1 | batagay
# Processing record 546 of Set 1 | urumqi
# Processing record 547 of Set 1 | xingcheng
# Processing record 548 of Set 1 | slave lake
# Processing record 549 of Set 1 | asheville
# Processing record 550 of Set 1 | geraldton
# Processing record 551 of Set 1 | qasigiannguit
# Processing record 552 of Set 1 | selma
# Processing record 553 of Set 1 | piacabucu
# Processing record 554 of Set 1 | kombissiri
# Processing record 555 of Set 1 | mongo
# Processing record 556 of Set 1 | coihaique
# Processing record 557 of Set 1 | sadasivpet
# Processing record 558 of Set 1 | buraydah
# Processing record 559 of Set 1 | mayari not found. Skipping...
# Processing record 560 of Set 1 | sorland
# Processing record 561 of Set 1 | monrovia
# Processing record 562 of Set 1 | shache
# Processing record 563 of Set 1 | sioux lookout
# Processing record 564 of Set 1 | ambon
# Processing record 565 of Set 1 | wahiawa
# Processing record 566 of Set 1 | the valley
# Processing record 567 of Set 1 | urayasu
# Processing record 568 of Set 1 | cawayan
# Processing record 569 of Set 1 | temaraia not found. Skipping...
# Processing record 570 of Set 1 | port hardy
# Processing record 571 of Set 1 | panaba
# Processing record 572 of Set 1 | lincoln
# Processing record 573 of Set 1 | libreville
# Processing record 574 of Set 1 | egvekinot
# Processing record 575 of Set 1 | luwuk
# Processing record 576 of Set 1 | altay
# Processing record 577 of Set 1 | isla mujeres
# Processing record 578 of Set 1 | boone
# Processing record 579 of Set 1 | haines junction
# Processing record 580 of Set 1 | farafangana
# Processing record 581 of Set 1 | cartagena del chaira
# Processing record 582 of Set 1 | port-gentil
# Processing record 583 of Set 1 | kangaatsiaq
# Processing record 584 of Set 1 | vila franca do campo
# Processing record 585 of Set 1 | quzhou
# Processing record 586 of Set 1 | mecca
# Processing record 587 of Set 1 | okhotsk
# Processing record 588 of Set 1 | grand-santi
# Processing record 589 of Set 1 | havelock
# Processing record 590 of Set 1 | mutsamudu not found. Skipping...
# Processing record 591 of Set 1 | nipawin
# Processing record 592 of Set 1 | straumen
# Processing record 593 of Set 1 | at-bashi
# Processing record 594 of Set 1 | amot
# Processing record 595 of Set 1 | ukiah
# Processing record 596 of Set 1 | ozernovskiy
# Processing record 597 of Set 1 | shelburne
# Processing record 598 of Set 1 | kuruman
# Processing record 599 of Set 1 | port hedland
# Processing record 600 of Set 1 | kaduqli
# Processing record 601 of Set 1 | san patricio
# Processing record 602 of Set 1 | agadir
# Processing record 603 of Set 1 | manzil tamim not found. Skipping...
# Processing record 604 of Set 1 | iwaki
# Processing record 605 of Set 1 | wonthaggi
# Processing record 606 of Set 1 | kidal
# Processing record 607 of Set 1 | shitanjing
# Processing record 608 of Set 1 | dwarka
# Great job! All raw data has now been collected

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Create a DataFrame
city_data_df = pd.DataFrame(city_data)

# Create the path to export the DataFrame into a .csv file
# To avoid any issues later, use encoding="utf-8"
output_path = "output_data/city_data.csv"
city_data_df.to_csv(output_path, encoding = "utf-8", index = False)

# Display the DataFrame
city_data_df.head()
# Out:
#          City Country  Latitude  Longitude  Temperature (F)  Humidity (%)  \
# 0       Vaini      TO    -21.20    -175.20            77.00            94
# 1   Bonavista      CA     48.65     -53.11            53.42            70
# 2     Salalah      OM     17.02      54.09            82.40            88
# 3  Butaritari      KI      3.07     172.79            83.68            79
# 4      Hobart      AU    -42.88     147.33            53.60            93
#
#    Wind speed (mph)  Cloud coverage    Datetime
# 0              9.17              75  1592781327
# 1             18.41              97  1592781459
# 2              5.82              40  1592781182
# 3             14.47              56  1592781057
# 4              8.05              75  1592781334

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
# Import date to include the date of analysis
from datetime import date

# Define a function for scatter plot
def scatter_plot(city_data_df, x_axis, y_axis):
    fig = plt.figure(figsize=(6,4))
    plt.scatter(city_data_df[x_axis], city_data_df[y_axis], marker = "o", color = "#0072BD", linewidths = 0.4, edgecolors = "black")
    today = date.today()
    plt.title(x_axis + " " + "vs. " + y_axis + " as on " + str(today))
    plt.xlabel(x_axis)
    plt.ylabel(y_axis)
    plt.grid(True)
    plt.tight_layout()
    output_plot = "output_data/" + x_axis + " " + "vs. " + y_axis + " as on " + str(today) + ".png"
    plt.savefig(output_plot, format = "png", bbox_inches = "tight", dpi = 300)

# %%
# Generate a scatter plot for Latitude vs. Temperature
x_axis = "Latitude"
y_axis = "Temperature (F)"
scatter_plot(city_data_df, x_axis, y_axis)

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
# Generate a scatter plot for Latitude vs. Humidity
x_axis = "Latitude"
y_axis = "Humidity (%)"
scatter_plot(city_data_df, x_axis, y_axis)

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
# Generate a scatter plot for Latitude vs. Cloudiness
x_axis = "Latitude"
y_axis = "Cloud coverage"
scatter_plot(city_data_df, x_axis, y_axis)

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Generate a scatter plot for Latitude vs. Wind Speed
x_axis = "Latitude"
y_axis = "Wind speed (mph)"
scatter_plot(city_data_df, x_axis, y_axis)

# %% [markdown]
# ## Linear Regression

# %%
# OPTIONAL: Create a function to create Linear Regression plots
def scatter_plot_by_hemisphere(city_data_df, x_axis, y_axis):
    fig = plt.figure(figsize=(6,4))
    plt.scatter(city_data_df[x_axis], city_data_df[y_axis], marker = "o", color = '#0072BD', linewidths = 0.4, edgecolors = "black")
    today = date.today()
    plt.xlabel(x_axis)
    plt.xlim(city_data_df[x_axis].min()-.75,city_data_df[x_axis].max() +.25)
    plt.ylabel(y_axis)
    plt.grid(False)
    plt.tight_layout()
    
    # Calculate and plot the regression
    (slope, intercept, rvalue, pvalue, stderr) = linregress(city_data_df[x_axis], city_data_df[y_axis])
    regress_values = city_data_df[x_axis] * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.plot(city_data_df[x_axis], regress_values,"r-")
    print(f" The r-squared is: {rvalue}")
    
    # Anchor the line annotation
    text =(line_eq + ', R$^{2}$ = ' + str(round(rvalue,2)))
    props = dict(boxstyle = 'round', facecolor = 'white', alpha = 0.4, edgecolor = 'none')        
    fig.text(0.15,0.2, text, size = 11, bbox = props, fontsize = 14, color ='red')
    
    # Prefix the corresponding hemisphere name to each plot
    if city_data_df['Latitude'].iloc[1] > 0:
        plt.title("Northern Hemisphere - " + x_axis + " " + "vs. " + y_axis + " with Linear Regression as on " + str(today))
        output_plot = "output_data/Northern_Hemisphere_"+ x_axis + " " + "vs. " + y_axis + "Linear Regression as on " + str(today) + ".png"
    else:
        plt.title("Southern Hemisphere - " + x_axis + " " + "vs. " + y_axis + " with Linear Regression as on " + str(today))
        output_plot = "output_data/Southern_Hemisphere_"+ x_axis + " " + "vs. " + y_axis + "Linear Regression as on " + str(today) + ".png"
    
    plt.savefig(output_plot, format = 'png', bbox_inches = 'tight', dpi = 300)

# %%
# Create Northern and Southern Hemisphere DataFrames
# Northern Hemisphere (greater than or equal to 0 degrees latitude) and Southern Hemisphere (less than 0 degrees latitude)
northern_hemisphere_df = city_data_df.loc[city_data_df["Latitude"]>=0]
southern_hemisphere_df = city_data_df.loc[city_data_df["Latitude"]<0]

# Check that all cities have been captures in either of the hemisphere DataFrames
print(f" Total count of cities in the City data DataFrame is {len(city_data_df)}")
print(f" Total count of cities in the Northern Hemisphere DataFrame is {len(northern_hemisphere_df)}")
print(f" Total count of cities in the Southern Hemisphere DataFrame is {len(southern_hemisphere_df)}")
# Out:
#  Total count of cities in the City data DataFrame is 559
#  Total count of cities in the Northern Hemisphere DataFrame is 391
#  Total count of cities in the Southern Hemisphere DataFrame is 168

# %% [markdown]
# ####  Northern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = "Latitude"
y_axis = "Temperature (F)"
scatter_plot_by_hemisphere(northern_hemisphere_df, x_axis, y_axis)
# Out:
#  The r-squared is: -0.6606120176098751

# %% [markdown]
# ####  Southern Hemisphere - Max Temp vs. Latitude Linear Regression

# %%
x_axis = "Latitude"
y_axis = "Temperature (F)"
scatter_plot_by_hemisphere(southern_hemisphere_df, x_axis, y_axis)
# Out:
#  The r-squared is: 0.8087619734619749

# %% [markdown]
# ####  Northern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = "Latitude"
y_axis = "Humidity (%)"
scatter_plot_by_hemisphere(northern_hemisphere_df, x_axis, y_axis)
# Out:
#  The r-squared is: -0.15769822342506723

# %% [markdown]
# ####  Southern Hemisphere - Humidity (%) vs. Latitude Linear Regression

# %%
x_axis = "Latitude"
y_axis = "Humidity (%)"
scatter_plot_by_hemisphere(southern_hemisphere_df, x_axis, y_axis)
# Out:
#  The r-squared is: -0.07674026417699722

# %% [markdown]
# ####  Northern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = "Latitude"
y_axis = "Cloud coverage"
scatter_plot_by_hemisphere(northern_hemisphere_df, x_axis, y_axis)
# Out:
#  The r-squared is: -0.09712109019761268

# %% [markdown]
# ####  Southern Hemisphere - Cloudiness (%) vs. Latitude Linear Regression

# %%
x_axis = "Latitude"
y_axis = "Cloud coverage"
scatter_plot_by_hemisphere(southern_hemisphere_df, x_axis, y_axis)
# Out:
#  The r-squared is: -0.07896344339251947

# %% [markdown]
# ####  Northern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = "Latitude"
y_axis = "Wind speed (mph)"
scatter_plot_by_hemisphere(northern_hemisphere_df, x_axis, y_axis)
# Out:
#  The r-squared is: -0.03363004148996088

# %% [markdown]
# ####  Southern Hemisphere - Wind Speed (mph) vs. Latitude Linear Regression

# %%
x_axis = "Latitude"
y_axis = "Wind speed (mph)"
scatter_plot_by_hemisphere(southern_hemisphere_df, x_axis, y_axis)
# Out:
#  The r-squared is: -0.014135591314270135

# %% [markdown]
# ## Observable trends

# %% [markdown]
# - There is a strong correlation between the latitude and temperature. The closer to the equator you are, the warmer the temperature gets. The further from the equator you are, the cooler the temperature gets.
# - Based on the data extracted today, there is a no strong correlation between the latitude and cloud coverage, humidity or wind speed.
# - Wind speeds of 0-15 mph have been observed across both hemispheres, irrespective of the latitude.
# - The northern hemisphere has relatively higher cloud coverage and wind speeds than the southern hemisphere.
# - It would be interesting to rerun this data set in a few months to observe influence of seasons on the various weather conditions.
